# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#matplotlib.inline

# %%
data=pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/train.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.drop(['PoolQC','Fence','MiscFeature','Alley','LotFrontage'],axis=1)
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
data1=data[['MSSubClass','LotShape','HouseStyle','OverallQual','OverallCond','RoofStyle','Foundation','TotalBsmtSF','1stFlrSF','2ndFlrSF','GarageArea','PoolArea','SaleType']]

# %%
data1
# Out:
#       MSSubClass LotShape HouseStyle  OverallQual  OverallCond RoofStyle  \
# 0             60      Reg     2Story            7            5     Gable
# 1             20      Reg     1Story            6            8     Gable
# 2             60      IR1     2Story            7            5     Gable
# 3             70      IR1     2Story            7            5     Gable
# 4             60      IR1     2Story            8            5     Gable
# ...          ...      ...        ...          ...          ...       ...
# 1455          60      Reg     2Story            6            5     Gable
# 1456          20      Reg     1Story            6            6     Gable
# 1457          70      Reg     2Story            7            9     Gable
# 1458          20      Reg     1Story            5            6       Hip
# 1459          20      Reg     1Story            5            6     Gable
#
#      Foundation  TotalBsmtSF  1stFlrSF  2ndFlrSF  GarageArea  PoolArea  \
# ...

# %%
numeric_data = data1.select_dtypes(include=[np.number])

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MSSubClass   1460 non-null   int64
#  1   OverallQual  1460 non-null   int64
#  2   OverallCond  1460 non-null   int64
#  3   TotalBsmtSF  1460 non-null   int64
#  4   1stFlrSF     1460 non-null   int64
#  5   2ndFlrSF     1460 non-null   int64
#  6   GarageArea   1460 non-null   int64
#  7   PoolArea     1460 non-null   int64
# dtypes: int64(8)
# memory usage: 91.4 KB

# %%
numeric_data.skew()
# Out:
# MSSubClass      1.407657
# OverallQual     0.216944
# OverallCond     0.693067
# TotalBsmtSF     1.524255
# 1stFlrSF        1.376757
# 2ndFlrSF        0.813030
# GarageArea      0.179981
# PoolArea       14.828374
# dtype: float64

# %%
categorical_data = data1.select_dtypes(exclude=[np.number])

# %%
categorical_data
# Out:
#      LotShape HouseStyle RoofStyle Foundation SaleType
# 0         Reg     2Story     Gable      PConc       WD
# 1         Reg     1Story     Gable     CBlock       WD
# 2         IR1     2Story     Gable      PConc       WD
# 3         IR1     2Story     Gable     BrkTil       WD
# 4         IR1     2Story     Gable      PConc       WD
# ...       ...        ...       ...        ...      ...
# 1455      Reg     2Story     Gable      PConc       WD
# 1456      Reg     1Story     Gable     CBlock       WD
# 1457      Reg     2Story     Gable      Stone       WD
# 1458      Reg     1Story       Hip     CBlock       WD
# 1459      Reg     1Story     Gable     CBlock       WD
#
# [1460 rows x 5 columns]

# %%
categorical_data.isnull().sum()
# Out:
# LotShape      0
# HouseStyle    0
# RoofStyle     0
# Foundation    0
# SaleType      0
# dtype: int64

# %%
categorical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LotShape    1460 non-null   object
#  1   HouseStyle  1460 non-null   object
#  2   RoofStyle   1460 non-null   object
#  3   Foundation  1460 non-null   object
#  4   SaleType    1460 non-null   object
# dtypes: object(5)
# memory usage: 57.2+ KB

# %%
categorical_data['LotShape'] = categorical_data['LotShape'].astype('category')
categorical_data['LotShape'] = categorical_data['LotShape'].cat.codes
categorical_data['LotShape']
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0       3
# 1       3
# 2       0
# 3       0
# 4       0
#        ..
# 1455    3
# 1456    3
# 1457    3
# 1458    3
# 1459    3
# Name: LotShape, Length: 1460, dtype: int8

# %%
categorical_data['HouseStyle']= categorical_data['HouseStyle'].astype('category')
categorical_data['HouseStyle']= categorical_data['HouseStyle'].cat.codes
categorical_data['HouseStyle'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([5, 2, 0, 1, 6, 7, 4, 3], dtype=int8)

# %%
categorical_data['RoofStyle'] = categorical_data['RoofStyle'].astype('category')
categorical_data['RoofStyle']= categorical_data['RoofStyle'].cat.codes
categorical_data['RoofStyle'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([1, 3, 2, 4, 0, 5], dtype=int8)

# %%
categorical_data['Foundation'] = categorical_data['Foundation'].astype('category')
categorical_data['Foundation']= categorical_data['Foundation'].cat.codes
categorical_data['Foundation'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([2, 1, 0, 5, 3, 4], dtype=int8)

# %%
categorical_data['SaleType'] = categorical_data['SaleType'].astype('category')
categorical_data['SaleType']= categorical_data['SaleType'].cat.codes
categorical_data['SaleType'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([8, 6, 0, 3, 4, 1, 5, 2, 7], dtype=int8)

# %%
categorical_data
# Out:
#       LotShape  HouseStyle  RoofStyle  Foundation  SaleType
# 0            3           5          1           2         8
# 1            3           2          1           1         8
# 2            0           5          1           2         8
# 3            0           5          1           0         8
# 4            0           5          1           2         8
# ...        ...         ...        ...         ...       ...
# 1455         3           5          1           2         8
# 1456         3           2          1           1         8
# 1457         3           5          1           4         8
# 1458         3           2          3           1         8
# 1459         3           2          1           1         8
#
# [1460 rows x 5 columns]

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MSSubClass   1460 non-null   int64
#  1   OverallQual  1460 non-null   int64
#  2   OverallCond  1460 non-null   int64
#  3   TotalBsmtSF  1460 non-null   int64
#  4   1stFlrSF     1460 non-null   int64
#  5   2ndFlrSF     1460 non-null   int64
#  6   GarageArea   1460 non-null   int64
#  7   PoolArea     1460 non-null   int64
# dtypes: int64(8)
# memory usage: 91.4 KB

# %%
train_data=pd.concat([numeric_data,categorical_data],axis=1)

# %%
train_data
# Out:
#       MSSubClass  OverallQual  OverallCond  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0             60            7            5          856       856       854
# 1             20            6            8         1262      1262         0
# 2             60            7            5          920       920       866
# 3             70            7            5          756       961       756
# 4             60            8            5         1145      1145      1053
# ...          ...          ...          ...          ...       ...       ...
# 1455          60            6            5          953       953       694
# 1456          20            6            6         1542      2073         0
# 1457          70            7            9         1152      1188      1152
# 1458          20            5            6         1078      1078         0
# 1459          20            5            6         1256      1256         0
#
# ...

# %%
train_data.skew()
# Out:
# MSSubClass      1.407657
# OverallQual     0.216944
# OverallCond     0.693067
# TotalBsmtSF     1.524255
# 1stFlrSF        1.376757
# 2ndFlrSF        0.813030
# GarageArea      0.179981
# PoolArea       14.828374
# LotShape       -0.610175
# HouseStyle      0.306755
# RoofStyle       1.473796
# Foundation      0.091217
# SaleType       -3.868638
# dtype: float64

# %%
X=train_data

# %%
X
# Out:
#       MSSubClass  OverallQual  OverallCond  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0             60            7            5          856       856       854
# 1             20            6            8         1262      1262         0
# 2             60            7            5          920       920       866
# 3             70            7            5          756       961       756
# 4             60            8            5         1145      1145      1053
# ...          ...          ...          ...          ...       ...       ...
# 1455          60            6            5          953       953       694
# 1456          20            6            6         1542      2073         0
# 1457          70            7            9         1152      1188      1152
# 1458          20            5            6         1078      1078         0
# 1459          20            5            6         1256      1256         0
#
# ...

# %%
y=data.SalePrice

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
y_pred
# Out:
# array([214348.10797571, 110342.12366108, 135043.05305775, 275628.91065506,
#        175724.96606283, 116407.76302114, 174721.18127399, 102074.5940915 ,
#        224928.14836392, 217539.0836055 , 241671.29921025,  93635.02615047,
#        130411.28675746, 258136.64664241, 154349.40053905, 206204.62971094,
#        185476.74942041, 125653.9351502 , 203574.20203636, 168670.54107597,
#        168010.81728445,  69404.34313389, 147819.30109344, 125716.32476197,
#        122912.58634277, 256777.53120069, 217011.41244328, 121211.41496016,
#        220251.9133335 , 124258.79669297, 274301.07464045, 206443.43762567,
#        146314.34968528, 148667.94278216, 192072.77625986, 215202.33341932,
#        221917.82519344, 119948.96915115, 267529.55650892, 175396.95088719,
#        190828.30424615, 218025.87455012, 262751.46682444, 186339.06119908,
#        215590.45906991, 163751.23168656, 221628.72470375, 130411.28675746,
# ...

# %%
regressor.score(x_test,y_test)
# Out:
# 0.7157373525374651

# %%
test_data=pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/test.csv")

# %%
test_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
data1=test_data[['MSSubClass','LotShape','HouseStyle','OverallQual','OverallCond','RoofStyle','Foundation','TotalBsmtSF','1stFlrSF','2ndFlrSF','GarageArea','PoolArea','SaleType']]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MSSubClass   1459 non-null   int64
#  1   LotShape     1459 non-null   object
#  2   HouseStyle   1459 non-null   object
#  3   OverallQual  1459 non-null   int64
#  4   OverallCond  1459 non-null   int64
#  5   RoofStyle    1459 non-null   object
#  6   Foundation   1459 non-null   object
#  7   TotalBsmtSF  1458 non-null   float64
#  8   1stFlrSF     1459 non-null   int64
#  9   2ndFlrSF     1459 non-null   int64
#  10  GarageArea   1458 non-null   float64
#  11  PoolArea     1459 non-null   int64
#  12  SaleType     1458 non-null   object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 148.3+ KB

# %%
data1.isnull().sum()
# Out:
# MSSubClass     0
# LotShape       0
# HouseStyle     0
# OverallQual    0
# OverallCond    0
# RoofStyle      0
# Foundation     0
# TotalBsmtSF    1
# 1stFlrSF       0
# 2ndFlrSF       0
# GarageArea     1
# PoolArea       0
# SaleType       1
# dtype: int64

# %%
numeric_data1 = data1.select_dtypes(include=[np.number])
categorical_data1 = data1.select_dtypes(exclude=[np.number])

# %%
numeric_data1
# Out:
#       MSSubClass  OverallQual  OverallCond  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0             20            5            6        882.0       896         0
# 1             20            6            6       1329.0      1329         0
# 2             60            5            5        928.0       928       701
# 3             60            6            6        926.0       926       678
# 4            120            8            5       1280.0      1280         0
# ...          ...          ...          ...          ...       ...       ...
# 1454         160            4            7        546.0       546       546
# 1455         160            4            5        546.0       546       546
# 1456          20            5            7       1224.0      1224         0
# 1457          85            5            5        912.0       970         0
# 1458          60            7            5        996.0       996      1004
#
#       GarageArea  PoolArea
# 0          730.0         0
# ...

# %%
numeric_data1.isnull().sum()
# Out:
# MSSubClass     0
# OverallQual    0
# OverallCond    0
# TotalBsmtSF    1
# 1stFlrSF       0
# 2ndFlrSF       0
# GarageArea     1
# PoolArea       0
# dtype: int64

# %%
numeric_data1['TotalBsmtSF']=numeric_data1['TotalBsmtSF'].fillna(0)
numeric_data1['TotalBsmtSF'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# array([ 882., 1329.,  928.,  926., 1280.,  763., 1168.,  789., 1300.,
#        1405.,  483.,  525.,  855.,  836., 1590., 1544., 1698., 1822.,
#        2846., 1671., 1370., 1324., 1145.,  384.,  847., 1629., 1595.,
#        1218., 1468.,  831.,  816., 1208., 1231., 1390., 1488.,  840.,
#         600.,  756.,  530., 1642.,  975., 1492., 1829., 1224.,  715.,
#        1232., 1209., 1510.,  533., 1728., 1140.,  782., 1080., 1604.,
#        1480., 1143., 1206., 1244.,  832.,  864.,  972.,  988.,  576.,
#        1175., 1395.,  709.,  936., 1347.,  827., 1027., 1008.,  678.,
# ...

# %%
numeric_data1['GarageArea']=numeric_data1['GarageArea'].fillna(0)
numeric_data1['GarageArea'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# array([ 730.,  312.,  482.,  470.,  506.,  440.,  420.,  393.,  525.,
#         511.,  264.,  320.,  308.,  751.,  868.,  678.,  958.,  756.,
#         484.,  430.,  437.,  400.,  433.,  962.,  880.,  676.,  528.,
#         429.,  461.,  762.,  713.,  588.,  480.,  496.,  852.,  592.,
#         596.,  535.,  660.,  441.,  490.,  504.,  517.,    0.,  315.,
#         576.,  620.,  263.,  318.,  305.,  280.,  240.,  551.,  780.,
#         288.,  624.,  363.,  200.,  572.,  180.,  365.,  231.,  450.,
#         416.,  591.,  690.,  522.,  467.,  209.,  366., 1017.,  615.,
# ...

# %%
numeric_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MSSubClass   1459 non-null   int64
#  1   OverallQual  1459 non-null   int64
#  2   OverallCond  1459 non-null   int64
#  3   TotalBsmtSF  1459 non-null   float64
#  4   1stFlrSF     1459 non-null   int64
#  5   2ndFlrSF     1459 non-null   int64
#  6   GarageArea   1459 non-null   float64
#  7   PoolArea     1459 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 91.3 KB

# %%
categorical_data1
# Out:
#      LotShape HouseStyle RoofStyle Foundation SaleType
# 0         Reg     1Story     Gable     CBlock       WD
# 1         IR1     1Story       Hip     CBlock       WD
# 2         IR1     2Story     Gable      PConc       WD
# 3         IR1     2Story     Gable      PConc       WD
# 4         IR1     1Story     Gable      PConc       WD
# ...       ...        ...       ...        ...      ...
# 1454      Reg     2Story     Gable     CBlock       WD
# 1455      Reg     2Story     Gable     CBlock       WD
# 1456      Reg     1Story     Gable     CBlock       WD
# 1457      Reg     SFoyer     Gable      PConc       WD
# 1458      Reg     2Story     Gable      PConc       WD
#
# [1459 rows x 5 columns]

# %%
categorical_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LotShape    1459 non-null   object
#  1   HouseStyle  1459 non-null   object
#  2   RoofStyle   1459 non-null   object
#  3   Foundation  1459 non-null   object
#  4   SaleType    1458 non-null   object
# dtypes: object(5)
# memory usage: 57.1+ KB

# %%
categorical_data1.isnull().sum()
# Out:
# LotShape      0
# HouseStyle    0
# RoofStyle     0
# Foundation    0
# SaleType      1
# dtype: int64

# %%
categorical_data1['SaleType'].unique()
# Out:
# array(['WD', 'COD', 'New', 'ConLD', 'Oth', 'Con', 'ConLw', 'ConLI', 'CWD',
#        nan], dtype=object)

# %%
categorical_data1['SaleType']=categorical_data1['SaleType'].fillna('COD')
categorical_data1['SaleType'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# array(['WD', 'COD', 'New', 'ConLD', 'Oth', 'Con', 'ConLw', 'ConLI', 'CWD'],
#       dtype=object)

# %%
categorical_data1.isnull().sum()
# Out:
# LotShape      0
# HouseStyle    0
# RoofStyle     0
# Foundation    0
# SaleType      0
# dtype: int64

# %%
categorical_data1['SaleType'] = categorical_data1['SaleType'].astype('category')
categorical_data1['SaleType']= categorical_data1['SaleType'].cat.codes
categorical_data1['SaleType'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([8, 0, 6, 3, 7, 2, 5, 4, 1], dtype=int8)

# %%
categorical_data1['Foundation'] = categorical_data1['Foundation'].astype('category')
categorical_data1['Foundation']= categorical_data1['Foundation'].cat.codes
categorical_data1['Foundation'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([1, 2, 0, 4, 3, 5], dtype=int8)

# %%
categorical_data1['RoofStyle'] = categorical_data1['RoofStyle'].astype('category')
categorical_data1['RoofStyle']= categorical_data1['RoofStyle'].cat.codes
categorical_data1['RoofStyle'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([1, 3, 2, 0, 4, 5], dtype=int8)

# %%
categorical_data1['HouseStyle']= categorical_data1['HouseStyle'].astype('category')
categorical_data1['HouseStyle']= categorical_data1['HouseStyle'].cat.codes
categorical_data1['HouseStyle'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([2, 4, 6, 0, 5, 3, 1], dtype=int8)

# %%
categorical_data1['LotShape'] = categorical_data1['LotShape'].astype('category')
categorical_data1['LotShape'] = categorical_data1['LotShape'].cat.codes
categorical_data1['LotShape'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([3, 0, 1, 2], dtype=int8)

# %%
test_data1=pd.concat([numeric_data1,categorical_data1],axis=1)

# %%
test_data1.head()
# Out:
#    MSSubClass  OverallQual  OverallCond  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0          20            5            6        882.0       896         0
# 1          20            6            6       1329.0      1329         0
# 2          60            5            5        928.0       928       701
# 3          60            6            6        926.0       926       678
# 4         120            8            5       1280.0      1280         0
#
#    GarageArea  PoolArea  LotShape  HouseStyle  RoofStyle  Foundation  SaleType
# 0       730.0         0         3           2          1           1         8
# 1       312.0         0         0           2          3           1         8
# 2       482.0         0         0           4          1           2         8
# 3       470.0         0         0           4          1           2         8
# 4       506.0         0         0           2          1           2         8

# %%
test=regressor.predict(test_data1)

# %%
test
# Out:
# array([134630.86308986, 179883.25287566, 166605.49224374, ...,
#        153805.08764417, 100832.70030886, 231580.22664813])

# %%
sub=pd.DataFrame({"Id":test_data.Id,"SalePrice":test})

# %%
sub
# Out:
#         Id      SalePrice
# 0     1461  134630.863090
# 1     1462  179883.252876
# 2     1463  166605.492244
# 3     1464  191900.722373
# 4     1465  218283.155988
# ...    ...            ...
# 1454  2915   61339.678059
# 1455  2916   67816.046354
# 1456  2917  153805.087644
# 1457  2918  100832.700309
# 1458  2919  231580.226648
#
# [1459 rows x 2 columns]

# %%
sub.to_csv('submission.csv',index=False)
